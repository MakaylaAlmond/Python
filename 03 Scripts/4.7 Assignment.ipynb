# %% [markdown]
# # importing libraries

# %%
#importing
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merged = pd.read_pickle(r'C:\Users\makay\Documents\Pythons files\Master folder\02 Data\Prepared data\orders_products_merged.pkl')

# %%
df = ords_prods_merged[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\makay\AppData\Local\Temp\ipykernel_12652\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\makay\AppData\Local\Temp\ipykernel_12652\1539861606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
 df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
 ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: order_dow, dtype: int64

# %%
result = []

# %%
for value in ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merged['busiet day'] = result

# %%
ords_prods_merged['busiet day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiet day, dtype: int64

# %% [markdown]
# # Assignment 4.7

# %%
#Creating new list using For Loop
dayresults = []

for value in ords_prods_merged["order_dow"]:
  if value == (0 or 1):
    dayresults.append("Busiest days")
  elif  value == (3 or 4):
    dayresults.append("slowest days")
  else:
    dayresults.append("Regularly busy days")

# %%
ords_prods_merged['busiest_days']=dayresults

# %% [markdown]
# # busiest days column created

# %%
ords_prods_merged['busiest_days'].value_counts(dropna=False)
# Out:
# Regularly busy days    22924286
# Busiest days            5665830
# slowest days            3844096
# Name: busiest_days, dtype: int64

# %% [markdown]
# # checked for accuracy

# %%
ords_prods_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2398795        1    prior             2          3
# 2             2    473747        1    prior             3          3
# 3             3   2254736        1    prior             4          4
# 4             4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  first_time_ordering  product_id  \
# 0                  8                     NaN                 True       196.0
# 1                  7                    15.0                False       196.0
# 2                 12                    21.0                False       196.0
# 3                  7                    29.0                False       196.0
# 4                 15                    28.0                False       196.0
#
#    ...  reordered  Unnamed: 0_y  product_name aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
periodresults = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value == (10 or 11 or 14 or 15 or 13 or 12 or 16 or 9):
    periodresults.append("Most orders")
  elif  value == (6 or 0 or 1 or 5 or 2 or 4 or 3):
    periodresults.append("Fewest orders")
  else:
    periodresults.append("Average orders")

# %%
ords_prods_merged['busiest_period_of_day']=periodresults

# %% [markdown]
# # busiest period of day column created

# %%
ords_prods_merged['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Average orders    29379052
# Most orders        2764390
# Fewest orders       290770
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # checked for accuracy

# %%
ords_prods_merged.to_pickle(r'C:\Users\makay\Documents\Pythons files\Master folder\02 Data\Prepared data\ords_prods_merged4.7.pkl')
